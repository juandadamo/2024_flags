# %%
from funciones_flag import *
import matplotlib.pyplot as plt
import numpy as np
from tikzplotlib import save as savetikz

# %%
x = np.linspace(0,1,50)
wx = w_n (BnL[1],x,A1=1,L=1)

# %%
fig,ax = plt.subplots()
ax.plot(x,wx)
ax.grid()
savetikz('/home/juan/Documents/Publicaciones/2025_euromech/flag/modo_elastico.tikz')
