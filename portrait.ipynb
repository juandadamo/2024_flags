# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
import scipy as sc
import sympy as sp
import pandas as pd
from funciones_flag import *
import glob
from skimage.filters import threshold_otsu
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x = np.linspace(0,1,50)
wx = w_n (BnL[2],x,A1=1,L=1)
wx = w_n_phase(BnL[1],x,1,1,1)

# %%
fig,ax = plt.subplots(figsize=(3,3))
lista_files = np.sort(glob.glob('/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_0001*'))
A = 0
for filei in lista_files[::6]:
    Ai = imread(filei)
 
    umbral = threshold_otsu(Ai)*0.1

    Ai[Ai<umbral] = 0
    Ai[Ai>umbral] = 1e3
    A += Ai
    A[A>umbral] = 1e3
    
    ax.imshow(A,cmap='binary')
#A[A>umbral] = 5e3
A += Ai
ax.imshow(A,cmap='binary')
ax.axis('off')

fig.tight_layout()
fig.savefig('/home/juan/Documents/Publicaciones/2025_euromech/flag/2D_flag_snapshots.png')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for i in np.linspace(0,np.pi,6):
    wx = w_n_phase(BnL[1],x,1.5,10,1)
    
    ax.plot(40+x*1029,(wx)*100+490,color='tab:orange')

# %%
filei,lista_files
# Out:
# ('/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000159.tiff',
#  array(['/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000150.tiff',
#         '/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000151.tiff',
#         '/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000152.tiff',
#         '/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000153.tiff',
#         '/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000154.tiff',
#         '/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000155.tiff',
#         '/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000156.tiff',
#         '/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000157.tiff',
#         '/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000158.tiff',
#         '/home/juan/data/balseiro/vid_2025-02-25_16-17-27/frame_000159.tiff'],
#        dtype='<U66'))
