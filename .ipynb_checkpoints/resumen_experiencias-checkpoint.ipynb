# %% [markdown]
# ## Mediciones Balseiro 2025
# ### inestabilidad de KH en papel
#
# #### Tunel de viento de 0 a 30 m/s, baja turbulencia
#
# Modelo: lámina de papel 80gr/cm$^2$

# %%
import matplotlib.pyplot as plt
#plt.rcParams['pgf.texsystem'] = 'pdflatex'
#plt.rcParams['text.usetex'] = True
#plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath}'

# %%
import numpy as np

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from tikzplotlib import save as savetikz

# %%
fig,ax = plt.subplots()
ax.semilogy(range(10))
ax.set_title('test')
ax.set_xlabel('x')
ax.set_ylabel('y')

ax.grid()
savetikz('test.tikz')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
